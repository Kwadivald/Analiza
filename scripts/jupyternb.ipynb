# %%
import pandas as pd

df_names = pd.read_csv('../data/smog1.csv')

# %% [markdown]
# ### Data frame description

# %%
df_names.shape
# Out:
# (1646, 12)

# %% [markdown]
# ### First 5 Data frame entries

# %%
df_names.head(5)
# Out:
#                                                 NAME  \
# 0  SZKO?A PODSTAWOWA IM. MARIANA FALSKIEGO W KRAS...
# 1                  SZKO?A PODSTAWOWA WE WRZ?SOWICACH
# 2                      ZESP?? SZK?? NR 1 W PSZCZYNIE
# 3  ZESP?? SZK?? IM. POWSTA?C?W WIELKOPOLSKICH W J...
# 4  SZKO?A PODSTAWOWA NR 7 IM. ?O?NIERZY WRZE?NIA ...
#
#                           STREET POST_CODE               CITY  LONGITUDE  \
# 0                    UL. SZKOLNA    63-522         KRASZEWICE  18.224030
# 1                    UL. SZKOLNA    32-040         WRZ?SOWICE  19.942820
# 2       UL. KAZIMIERZA WIELKIEGO    43-200           PSZCZYNA  18.945706
# 3                        SZKOLNA    63-421  JANK?W PRZYGODZKI  17.788907
# 4  UL. M?CZENNIK?W O?WI?CIMSKICH    43-229           ?WIKLICE  18.989839
#
#     LATITUDE  HUMIDITY_AVG  PRESSURE_AVG  TEMPERATURE_AVG  PM10_AVG  \
# 0  51.515630     99.900000   1016.266667        18.633333      4.10
# ...

# %% [markdown]
# ### Last 5 Data frame entries

# %%
df_names.tail(5)
# Out:
#                                                    NAME  \
# 1641  SZKO?A PODSTAWOWA IM.BOHATER?W WRZE?NIA 1939R....
# 1642                     PRZEDSZKOLE NR 10 W PIASECZNIE
# 1643   SZKO?A PODSTAWOWA IM. JANA PAW?A II W WILCZKOWIE
# 1644                     PRZEDSZKOLE SAMORZ?DOWE W GOLI
# 1645                SPO?ECZNA SZKO?A PODSTAWOWA W GZACH
#
#                       STREET POST_CODE       CITY  LONGITUDE   LATITUDE  \
# 1641            KONOPNICKIEJ    34-240   JORDAN?W  19.834938  49.653449
# 1642             NADARZY?SKA    05-500  PIASECZNO  21.017680  52.072370
# 1643  UL. MIKO?AJA KOPERNIKA    55-020   WILCZK?W  16.989396  50.966512
# 1644                     NaN    63-800       GOLA  16.944640  51.870920
# 1645                     NaN    06-126        GZY  20.925636  52.744815
#
#       HUMIDITY_AVG  PRESSURE_AVG  TEMPERATURE_AVG   PM10_AVG   PM25_AVG  \
# 1641     84.109091    963.645455        18.972727  15.245455  14.972727
# ...
