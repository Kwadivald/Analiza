# %%
import pandas as pd

df_names = pd.read_csv('../scripts_different/names.csv')

# %% [markdown]
# ### Data frame description

# %%
df_names.shape

# %% [markdown]
# ### First 5 Data frame entries

# %%
df_names.head(5)

# %% [markdown]
# ### Last 5 Data frame entries

# %%
df_names.tail(5)
